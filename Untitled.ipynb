# %% [markdown]
# # Loading The Book

# %%
with open("miracle_in_the_andes.txt", "r", encoding="utf-8") as file:
    book = file.read()

# %% [markdown]
# # The most used words(non-articles)

# %%
import re 
pattern = re.compile("[a-zA-Z]+")
findings = re.findall(pattern, book.lower())
findings[:5]
# Out:
# ['chapter', 'before', 'it', 'was', 'friday']

# %%
d = {}
for word in findings:
    if word in d.keys():
        d[word] = d[word] + 1
    else:
        d[word] =1
d
# Out:
# {'chapter': 11,
#  'before': 93,
#  'it': 800,
#  'was': 1430,
#  'friday': 1,
#  'the': 5346,
#  'thirteenth': 1,
#  'of': 2060,
#  'october': 8,
#  'we': 1226,
#  'joked': 3,
#  'about': 134,
#  'that': 1001,
#  'flying': 15,
#  'over': 101,
#  'andes': 79,
#  'on': 576,
#  'such': 57,
#  'an': 205,
#  'unlucky': 1,
#  'day': 88,
#  'but': 679,
#  'young': 34,
#  'men': 23,
#  'make': 88,
#  'those': 74,
#  'kinds': 3,
#  'jokes': 3,
#  'so': 333,
#  'easily': 8,
#  'our': 496,
#  'flight': 26,
#  'had': 941,
#  'originated': 1,
#  'one': 249,
#  'earlier': 9,
#  'in': 1419,
#  'montevideo': 27,
#  'my': 1169,
#  'hometown': 1,
#  'its': 53,
#  'destination': 2,
#  'santiago': 21,
#  'chile': 26,
#  'a': 1566,
#  'chartered': 2,
#  'fairchild': 75,
#  'twin': 1,
#  'engine': 5,
#  'turboprop': 1,
#  'carrying': 5,
#  'rugby': 49,
#  'team': 50,
#  'old': 51,
#  'christians': 19,
#  'club': 5,
#  'to': 2400,
#  'play': 19,
#  'exhibition': 2,
#  'match': 14,
#  'against': 42,
#  'top': 26,
#  'chilean': 20,
#  'squad': 4,
#  'there': 269,
#  'were': 523,
#  'forty': 5,
#  'five': 21,
#  'people': 30,
#  'aboard': 1,
#  'including': 13,
#  'four': 15,
#  'crew': 10,
#  'members': 10,
#  'pilot': 12,
#  'copilot': 11,
#  'mechanic': 7,
#  'and': 2795,
#  'steward': 5,
#  'most': 73,
#  'passengers': 11,
#  'teammates': 9,
#  'also': 44,
#  'accompanied': 1,
#  'by': 257,
#  'friends': 83,
#  'family': 38,
#  'other': 88,
#  'supporters': 5,
#  'mother': 92,
#  'eugenia': 6,
#  'younger': 7,
#  'sister': 45,
#  'susy': 70,
#  'who': 167,
#  'sitting': 17,
#  'across': 39,
#  'aisle': 5,
#  'row': 13,
#  'front': 24,
#  'me': 617,
#  'original': 1,
#  'itinerary': 1,
#  'fly': 20,
#  'nonstop': 1,
#  'trip': 29,
#  'three': 49,
#  'half': 26,
#  'hours': 80,
#  'after': 134,
#  'just': 109,
#  'few': 71,
#  'reports': 5,
#  'bad': 15,
#  'weather': 21,
#  'mountains': 147,
#  'ahead': 30,
#  'forced': 40,
#  's': 420,
#  'julio': 1,
#  'ferradas': 7,
#  'put': 14,
#  'plane': 116,
#  'down': 174,
#  'spanish': 3,
#  'colonial': 1,
#  'town': 6,
#  'mendoza': 15,
#  'which': 87,
#  'lies': 8,
#  'east': 20,
#  'andean': 8,
#  'foothills': 9,
#  'landed': 5,
#  'at': 481,
#  'lunchtime': 1,
#  'with': 632,
#  'hopes': 20,
#  'would': 575,
#  'be': 316,
#  'back': 115,
#  'air': 73,
#  'not': 282,
#  'encouraging': 1,
#  'soon': 77,
#  'clear': 36,
#  'have': 252,
#  'stay': 34,
#  'night': 105,
#  'none': 20,
#  'us': 519,
#  'liked': 10,
#  'idea': 22,
#  'losing': 8,
#  'from': 452,
#  'charming': 1,
#  'place': 76,
#  'decided': 30,
#  'best': 36,
#  'time': 182,
#  'some': 153,
#  'guys': 17,
#  'relaxed': 2,
#  'sidewalk': 4,
#  'caf': 3,
#  'along': 32,
#  'broad': 14,
#  'tree': 3,
#  'lined': 1,
#  'boulevards': 1,
#  'or': 228,
#  'went': 31,
#  'sightseeing': 1,
#  'city': 7,
#  'historic': 2,
#  'neighborhoods': 2,
#  'i': 2729,
#  'spent': 38,
#  'afternoon': 39,
#  'watching': 17,
#  'auto': 4,
#  'race': 12,
#  'track': 6,
#  'outside': 34,
#  'evening': 14,
#  'movie': 4,
#  'while': 51,
#  'others': 126,
#  'dancing': 3,
#  'argentinean': 1,
#  'girls': 25,
#  'they': 360,
#  'met': 16,
#  'their': 227,
#  'exploring': 1,
#  'quaint': 1,
#  'gift': 3,
#  'shops': 1,
#  'buying': 2,
#  'presents': 1,
#  'for': 705,
#  'souvenirs': 1,
#  'home': 67,
#  'especially': 19,
#  'pleased': 1,
#  'find': 78,
#  'pair': 6,
#  'red': 8,
#  'baby': 8,
#  'shoes': 16,
#  'small': 62,
#  'boutique': 1,
#  'she': 181,
#  'thought': 106,
#  'perfect': 13,
#  'graciela': 13,
#  'new': 30,
#  'boy': 20,
#  'slept': 16,
#  'late': 24,
#  'next': 36,
#  'morning': 70,
#  'when': 273,
#  'woke': 12,
#  'anxious': 3,
#  'leave': 42,
#  'still': 137,
#  'no': 251,
#  'word': 5,
#  'departure': 7,
#  'all': 373,
#  'separate': 2,
#  'ways': 17,
#  'see': 115,
#  'little': 60,
#  'more': 209,
#  'finally': 49,
#  'received': 2,
#  'gather': 7,
#  'airport': 6,
#  'p': 3,
#  'm': 41,
#  'sharp': 13,
#  'arrived': 14,
#  'only': 158,
#  'discover': 1,
#  'his': 530,
#  'dante': 2,
#  'lagurara': 12,
#  'yet': 14,
#  'whether': 6,
#  'reacted': 1,
#  'this': 320,
#  'news': 27,
#  'frustration': 3,
#  'anger': 10,
#  'understood': 38,
#  'difficult': 24,
#  'decision': 11,
#  'confronting': 1,
#  'pilots': 22,
#  'warned': 1,
#  'turbulence': 7,
#  'path': 34,
#  'speaking': 10,
#  'cargo': 3,
#  'flown': 5,
#  'confident': 4,
#  'could': 252,
#  'safely': 10,
#  'above': 67,
#  'troubling': 2,
#  'problem': 5,
#  'already': 39,
#  'early': 22,
#  'boarded': 4,
#  'necessary': 1,
#  'arrangements': 1,
#  'made': 104,
#  'officials': 5,
#  'well': 47,
#  'past': 19,
#  'two': 78,
#  'o': 6,
#  'clock': 7,
#  'warm': 48,
#  'rises': 1,
#  'argentine': 9,
#  'meets': 1,
#  'frigid': 16,
#  'snowline': 2,
#  'create': 4,
#  'treacherous': 5,
#  'instability': 1,
#  'atmosphere': 6,
#  'knew': 155,
#  'dangerous': 8,
#  'way': 164,
#  'predict': 1,
#  'where': 112,
#  'these': 98,
#  'swirling': 6,
#  'currents': 2,
#  'might': 57,
#  'strike': 2,
#  'if': 198,
#  'got': 15,
#  'hold': 31,
#  'tossed': 7,
#  'around': 88,
#  'like': 165,
#  'toy': 1,
#  'hand': 18,
#  'couldn': 48,
#  't': 290,
#  'aircraft': 10,
#  'f': 3,
#  'leased': 2,
#  'uruguayan': 15,
#  'force': 37,
#  'laws': 2,
#  'argentina': 8,
#  'forbade': 2,
#  'foreign': 1,
#  'military': 6,
#  'soil': 2,
#  'longer': 35,
#  'than': 118,
#  'twenty': 20,
#  'since': 43,
#  'almost': 27,
#  'up': 161,
#  'fast': 18,
#  'should': 33,
#  'take': 60,
#  'off': 99,
#  'brave': 11,
#  'skies': 12,
#  'end': 34,
#  'vacation': 2,
#  'as': 700,
#  'pondered': 2,
#  'options': 2,
#  'impatience': 2,
#  'grew': 37,
#  'lost': 57,
#  'frustrated': 1,
#  'bold': 2,
#  'fearless': 1,
#  'full': 16,
#  'ourselves': 47,
#  'angered': 2,
#  'slipping': 9,
#  'away': 78,
#  'because': 43,
#  'what': 201,
#  'regarded': 1,
#  'timidity': 1,
#  'did': 121,
#  'hide': 3,
#  'feelings': 7,
#  'saw': 117,
#  'jeered': 1,
#  'whistled': 1,
#  'them': 275,
#  'teased': 2,
#  'questioned': 2,
#  'competence': 1,
#  'hired': 3,
#  'you': 381,
#  'someone': 48,
#  'shouted': 34,
#  'want': 39,
#  'do': 134,
#  'is': 274,
#  'know': 100,
#  'behavior': 4,
#  'influenced': 1,
#  'seem': 10,
#  'unsettle': 1,
#  'last': 61,
#  'consultation': 1,
#  'glanced': 22,
#  'crowd': 3,
#  'waiting': 29,
#  'restlessly': 2,
#  'answer': 12,
#  'announced': 5,
#  'continue': 8,
#  'greeted': 2,
#  'rowdy': 1,
#  'cheer': 1,
#  'departed': 2,
#  'eighteen': 4,
#  'minutes': 14,
#  'local': 2,
#  'climbed': 38,
#  'banked': 4,
#  'steeply': 4,
#  'into': 229,
#  'left': 83,
#  'turn': 20,
#  'south': 16,
#  'rising': 12,
#  'right': 68,
#  'western': 14,
#  'horizon': 8,
#  'through': 134,
#  'windows': 8,
#  'side': 49,
#  'fuselage': 140,
#  'gazed': 9,
#  'thundered': 3,
#  'dry': 10,
#  'plateau': 4,
#  'below': 22,
#  'black': 22,
#  'mirage': 1,
#  'bleak': 2,
#  'majestic': 3,
#  'astonishingly': 1,
#  'vast': 7,
#  'huge': 16,
#  'simple': 27,
#  'sight': 10,
#  'heart': 52,
#  'rooted': 1,
#  'massive': 8,
#  'swells': 1,
#  'bedrock': 1,
#  'colossal': 4,
#  'bases': 2,
#  'spread': 13,
#  'miles': 18,
#  'ridges': 21,
#  'soared': 3,
#  'flatlands': 1,
#  'peak': 6,
#  'crowding': 1,
#  'seemed': 84,
#  'form': 11,
#  'fortress': 2,
#  'wall': 37,
#  'poetically': 1,
#  'inclined': 1,
#  'man': 50,
#  'warning': 2,
#  'great': 59,
#  'authority': 3,
#  'held': 15,
#  'ground': 26,
#  'impossible': 23,
#  'think': 77,
#  'living': 31,
#  'things': 58,
#  'minds': 4,
#  'hearts': 5,
#  'brooding': 2,
#  'awareness': 2,
#  'wonder': 5,
#  'ancients': 1,
#  'holy': 3,
#  'places': 15,
#  'doorstep': 1,
#  'heaven': 3,
#  'dwelling': 2,
#  'gods': 1,
#  'uruguay': 24,
#  'low': 13,
#  'lying': 40,
#  'country': 13,
#  'knowledge': 8,
#  'any': 61,
#  'limited': 2,
#  'read': 5,
#  'books': 7,
#  'school': 26,
#  'learned': 15,
#  'range': 4,
#  'extensive': 1,
#  'mountain': 183,
#  'system': 7,
#  'world': 52,
#  'running': 14,
#  'length': 3,
#  'america': 5,
#  'venezuela': 1,
#  'north': 4,
#  'southern': 3,
#  'tip': 6,
#  'continent': 1,
#  'tierra': 1,
#  'del': 16,
#  'fuego': 1,
#  'are': 181,
#  'second': 50,
#  'highest': 6,
#  'planet': 3,
#  'terms': 3,
#  'average': 2,
#  'elevation': 1,
#  'himalayas': 1,
#  'higher': 6,
#  'heard': 47,
#  'refer': 2,
#  'earth': 9,
#  'geological': 1,
#  'wonders': 3,
#  'view': 16,
#  'airplane': 6,
#  'gave': 48,
#  'visceral': 2,
#  'understanding': 4,
#  'meant': 8,
#  'west': 49,
#  'sprawled': 1,
#  'far': 50,
#  'eye': 16,
#  'even': 106,
#  'though': 23,
#  'many': 89,
#  'height': 4,
#  'mass': 2,
#  'impassable': 5,
#  'fact': 31,
#  'concerned': 6,
#  'exactly': 7,
#  'due': 2,
#  'region': 4,
#  'separates': 1,
#  'cities': 2,
#  'sections': 1,
#  'entire': 6,
#  'chain': 2,
#  'tallest': 4,
#  'somewhere': 13,
#  'out': 164,
#  'example': 14,
#  'aconcagua': 1,
#  'hemisphere': 2,
#  'seven': 10,
#  'summit': 25,
#  'feet': 93,
#  'stands': 2,
#  'shy': 3,
#  'everest': 1,
#  'has': 26,
#  'giants': 1,
#  'neighbors': 5,
#  'foot': 22,
#  'mount': 6,
#  'mercedario': 1,
#  'tupongato': 1,
#  'tall': 14,
#  'surrounding': 5,
#  'behemoths': 1,
#  'peaks': 18,
#  'elevations': 1,
#  'between': 27,
#  'wild': 11,
#  'reaches': 2,
#  'ever': 40,
#  'bothered': 2,
#  'name': 8,
#  'towering': 4,
#  'summits': 6,
#  'chance': 32,
#  'maximum': 1,
#  'cruising': 2,
#  'altitude': 26,
#  'direct': 4,
#  'route': 17,
#  'instead': 15,
#  'charted': 1,
#  'course': 20,
#  'hundred': 23,
#  'planch': 5,
#  'n': 17,
#  'pass': 14,
#  'narrow': 12,
#  'corridor': 1,
#  'enough': 62,
#  'eastern': 9,
#  'always': 78,
#  'until': 67,
#  'reached': 34,
#  'then': 195,
#  'd': 116,
#  'weave': 4,
#  'cleared': 6,
#  'hour': 20,
#  'dark': 29,
#  'first': 121,
#  'leg': 19,
#  'calm': 17,
#  'less': 13,
#  'vicinity': 1,
#  'didn': 57,
#  'details': 6,
#  'help': 49,
#  'noticing': 3,
#  'distance': 25,
#  'now': 198,
#  'directly': 6,
#  'cordillera': 17,
#  'window': 12,
#  'seat': 34,
#  'watched': 16,
#  'flat': 10,
#  'featureless': 1,
#  'landscape': 7,
#  'leap': 3,
#  'rugged': 9,
#  'heaving': 3,
#  'buckling': 1,
#  'awesome': 4,
#  'convolutions': 1,
#  'true': 23,
#  'shark': 1,
#  'finned': 1,
#  'raised': 9,
#  'themselves': 18,
#  'soaring': 3,
#  'sails': 1,
#  'menacing': 1,
#  'pushed': 12,
#  'gigantic': 3,
#  'spearheads': 1,
#  'broken': 21,
#  'blades': 4,
#  'hatchets': 1,
#  'glacial': 2,
#  'valleys': 3,
#  'gashed': 2,
#  'steep': 28,
#  'slopes': 68,
#  'forming': 1,
#  'rows': 3,
#  'deep': 46,
#  'winding': 7,
#  'snow': 227,
#  'packed': 17,
#  'corridors': 1,
#  'stacked': 6,
#  'folded': 2,
#  'upon': 11,
#  'endless': 8,
#  'maze': 2,
#  'ice': 23,
#  'rock': 63,
#  'winter': 5,
#  'given': 23,
#  'spring': 6,
#  'temperatures': 13,
#  'routinely': 2,
#  'dipped': 4,
#  'degrees': 5,
#  'zero': 4,
#  'fahrenheit': 1,
#  'desert': 2,
#  'avalanches': 2,
#  'blizzards': 3,
#  'killing': 5,
#  'gale': 1,
#  'winds': 15,
#  'common': 8,
#  'previous': 5,
#  'been': 177,
#  'severe': 8,
#  'record': 1,
#  'snowfalls': 1,
#  'several': 21,
#  'color': 3,
#  'muted': 3,
#  'patches': 4,
#  'gray': 8,
#  'softness': 5,
#  'life': 161,
#  'looked': 58,
#  'wildness': 2,
#  'laugh': 3,
#  'arrogance': 2,
#  'anyone': 23,
#  'human': 36,
#  'beings': 4,
#  'conquered': 4,
#  'noticed': 7,
#  'wisps': 1,
#  'fog': 8,
#  'gathering': 8,
#  'felt': 127,
#  'shoulder': 8,
#  'switch': 1,
#  'seats': 36,
#  'nando': 64,
#  'look': 45,
#  'friend': 31,
#  'panchito': 54,
#  'beside': 29,
#  'nodded': 29,
#  'rose': 17,
#  'stood': 18,
#  'change': 13,
#  'yelled': 1,
#  'turned': 45,
#  'catch': 6,
#  'ball': 29,
#  'rear': 11,
#  'cabin': 12,
#  'passed': 46,
#  'forward': 54,
#  'sank': 12,
#  'laughing': 4,
#  'talking': 11,
#  'moving': 18,
#  'visiting': 2,
#  'oldest': 4,
#  'amigo': 2,
#  'guido': 14,
#  'magri': 5,
#  'playing': 18,
#  'cards': 3,
#  'began': 97,
#  'bouncing': 3,
#  'stepped': 10,
#  'tried': 55,
#  'he': 946,
#  'settle': 2,
#  'please': 22,
#  'your': 67,
#  'players': 13,
#  'traveling': 6,
#  'teams': 6,
#  'took': 65,
#  'regular': 2,
#  'matches': 5,
#  'seriously': 8,
#  'really': 18,
#  'holiday': 2,
#  'feeling': 17,
#  'begun': 7,
#  'fine': 13,
#  'thing': 31,
#  'much': 97,
#  'together': 46,
#  'years': 42,
#  'learning': 2,
#  'training': 3,
#  'heartbreaking': 2,
#  'losses': 5,
#  'hard': 76,
#  'fought': 10,
#  'wins': 1,
#  'grown': 12,
#  'drawing': 8,
#  'each': 97,
#  'strengths': 2,
#  'trust': 18,
#  'another': 66,
#  'pressure': 7,
#  'game': 35,
#  'shaped': 7,
#  'friendships': 5,
#  'characters': 2,
#  'brought': 20,
#  'brothers': 25,
#  'known': 14,
#  'ten': 17,
#  'days': 77,
#  'schoolboy': 1,
#  'ruggers': 2,
#  'under': 35,
#  'guidance': 5,
#  'irish': 3,
#  'christian': 17,
#  'stella': 11,
#  'maris': 11,
#  'come': 64,
#  'ireland': 1,
#  'invitation': 4,
#  'group': 29,
#  'catholic': 9,
#  'parents': 17,
#  'wanted': 52,
#  'found': 126,
#  'private': 5,
#  'answered': 20,
#  'call': 13,
#  'created': 6,
#  'college': 3,
#  'boys': 42,
#  'ages': 2,
#  'nine': 5,
#  'sixteen': 6,
#  'located': 2,
#  'carrasco': 10,
#  'neighborhood': 5,
#  'students': 2,
#  'lived': 17,
#  'goal': 5,
#  'education': 2,
#  'build': 9,
#  'character': 4,
#  'intellect': 1,
#  'teaching': 7,
#  'methods': 1,
#  'stressed': 1,
#  'discipline': 5,
#  'piety': 1,
#  'selflessness': 4,
#  'respect': 17,
#  'promote': 1,
#  'values': 4,
#  'classroom': 1,
#  'discouraged': 1,
#  'natural': 10,
#  'american': 3,
#  'passion': 13,
#  'soccer': 8,
#  'fostered': 1,
#  'selfishness': 1,
#  'egotism': 1,
#  'steered': 2,
#  'toward': 49,
#  'rougher': 1,
#  'earthier': 1,
#  'generations': 1,
#  'virtually': 1,
#  'unknown': 15,
#  'strange': 6,
#  'brutal': 7,
#  'painful': 10,
#  'pushing': 3,
#  'shoving': 5,
#  'wide': 13,
#  'open': 31,
#  'flair': 1,
#  'firmly': 9,
#  'believed': 12,
#  'qualities': 1,
#  'required': 14,
#  'master': 1,
#  'sport': 7,
#  'same': 48,
#  'characteristics': 1,
#  'needed': 27,
#  'live': 30,
#  'decent': 3,
#  'humility': 1,
#  'tenacity': 2,
#  'self': 18,
#  'devotion': 1,
#  'determined': 4,
#  'long': 95,
#  'learn': 2,
#  'once': 40,
#  'set': 34,
#  'purpose': 8,
#  'sway': 1,
#  'aside': 4,
#  'balls': 2,
#  'acquainted': 1,
#  'fat': 4,
#  'pointed': 6,
#  'pigskin': 1,
#  'used': 20,
#  'tough': 7,
#  'practices': 1,
#  'fields': 7,
#  'behind': 41,
#  'started': 18,
#  'scratch': 4,
#  'drilling': 1,
#  'intricacies': 1,
#  'mucks': 1,
#  'rauls': 1,
#  'scrumdowns': 1,
#  'lineouts': 2,
#  'how': 156,
#  'kick': 4,
#  'tackle': 1,
#  'wore': 9,
#  'pads': 1,
#  'helmets': 1,
#  'expected': 7,
#  'aggressively': 2,
#  'physical': 14,
#  'courage': 34,
#  'brute': 3,
#  'strength': 72,
#  'sound': 17,
#  'strategy': 1,
#  'quick': 7,
#  'thinking': 36,
#  'agility': 4,
#  'demanded': 3,
#  'develop': 2,
#  'unshakeable': 1,
#  'sense': 58,
#  'explained': 12,
#  'falls': 4,
#  'knocked': 3,
#  'becomes': 2,
#  'grass': 6,
#  'saying': 5,
#  'downed': 1,
#  'player': 6,
#  'can': 138,
#  'stomped': 2,
#  'trampled': 1,
#  'opposition': 3,
#  'part': 24,
#  'turf': 3,
#  'taught': 16,
#  'behave': 2,
#  'teammate': 7,
#  'must': 72,
#  'become': 24,
#  'protector': 1,
#  'sacrifice': 1,
#  'yourself': 11,
#  'shield': 5,
#  'him': 350,
#  'count': 5,
#  'level': 20,
#  'moral': 1,
#  'ironclad': 1,
#  'belief': 6,
#  'devoutly': 1,
#  'importance': 4,
#  'striving': 3,
#  'suffering': 46,
#  'sacrificing': 1,
#  'pursuit': 3,
#  'passionate': 3,
#  'point': 34,
#  'choice': 19,
#  'believe': 25,
#  'understand': 25,
#  'deeply': 8,
#  'simplest': 4,
#  'object': 2,
#  'gain': 2,
#  'control': 18,
#  'usually': 6,
#  'combined': 1,
#  'use': 27,
#  'cunning': 1,
#  'speed': 17,
#  'passing': 7,
#  'deftly': 1,
#  'sprinting': 1,
#  'advance': 1,
#  'try': 29,
#  'line': 28,
#  'score': 3,
#  'dazzling': 1,
#  'pinpoint': 1,
#  'passes': 2,
#  'brilliant': 7,
#  'evasive': 1,
#  'maneuvers': 1,
#  'essence': 3,
#  'controlled': 2,
#  'melee': 1,
#  'scrum': 18,
#  'signature': 1,
#  'formation': 1,
#  'scrummage': 1,
#  'forms': 3,
#  'tight': 5,
#  'huddle': 6,
#  'crouching': 3,
#  'arms': 48,
#  'interlocked': 1,
#  'tightly': 3,
#  'woven': 1,
#  'wedge': 1,
#  'scrums': 2,
#  'square': 5,
#  'butts': 1,
#  'shoulders': 15,
#  'rough': 4,
#  'closed': 9,
#  'circle': 4,
#  'official': 1,
#  'signal': 4,
#  'rolled': 13,
#  'tries': 1,
#  'push': 7,
#  'own': 67,
#  'legs': 40,
#  'pluck': 1,
#  'free': 10,
#  'will': 176,
#  'start': 12,
#  'attack': 4,
#  'inside': 38,
#  'ferocious': 2,
#  'knees': 16,
#  ...}

# %%
d_list = [(key, value) for (key, value) in d.items()]
d_list = sorted(d_list, reverse=True)
d_list
# Out:
# [('zones', 1),
#  ('zone', 1),
#  ('zombies', 1),
#  ('zolder', 1),
#  ('zigzagged', 1),
#  ('zero', 4),
#  ('zerbino', 23),
#  ('zeal', 1),
#  ('zandvoort', 1),
#  ('zampa', 1),
#  ('youth', 2),
#  ('yourself', 11),
#  ('your', 67),
#  ('youngest', 4),
#  ('younger', 7),
#  ('young', 34),
#  ('you', 381),
#  ('yielding', 1),
#  ('yet', 14),
#  ('yes', 11),
#  ('yelp', 1),
#  ('yellowish', 1),
#  ('yelled', 1),
#  ('years', 42),
#  ('yearning', 1),
#  ('year', 17),
#  ('yawning', 1),
#  ('yards', 22),
#  ('yard', 1),
#  ('yanked', 3),
#  ('y', 2),
#  ('xv', 3),
#  ('xenia', 2),
#  ('wry', 1),
#  ('wrote', 1),
#  ('wrong', 9),
#  ('written', 1),
#  ('writing', 2),
#  ('write', 5),
#  ('wrist', 1),
#  ('wretched', 1),
#  ('wrestled', 1),
#  ('wrench', 1),
#  ('wrecked', 3),
#  ('wreckage', 12),
#  ('wrapping', 3),
#  ('wrapped', 8),
#  ('wrap', 2),
#  ('woven', 1),
#  ('wove', 1),
#  ('wounds', 9),
#  ('wounded', 2),
#  ('wound', 9),
#  ('wouldn', 7),
#  ('would', 575),
#  ('worthy', 1),
#  ('worth', 3),
#  ('worst', 10),
#  ('worsened', 1),
#  ('worse', 12),
#  ('worrying', 1),
#  ('worry', 7),
#  ('worries', 1),
#  ('worried', 21),
#  ('worn', 1),
#  ('worlds', 2),
#  ('worldly', 1),
#  ('world', 52),
#  ('works', 2),
#  ('working', 17),
#  ('workers', 5),
#  ('worker', 2),
#  ('worked', 17),
#  ('work', 53),
#  ('wore', 9),
#  ('words', 29),
#  ('word', 5),
#  ('woolen', 1),
#  ('wool', 1),
#  ('wooden', 1),
#  ('wooded', 1),
#  ('wood', 3),
#  ('wonders', 3),
#  ('wondering', 1),
#  ('wonderful', 3),
#  ('wondered', 18),
#  ('wonder', 5),
#  ('won', 11),
#  ('women', 4),
#  ('woman', 21),
#  ('woke', 12),
#  ('wobbly', 1),
#  ('wobbling', 1),
#  ('wobbled', 2),
#  ('wobble', 1),
#  ('wizard', 1),
#  ('witted', 2),
#  ('wits', 2),
#  ('withstand', 1),
#  ('without', 41),
#  ('within', 6),
#  ('withered', 2),
#  ('withdrawn', 3),
#  ('with', 632),
#  ('wit', 2),
#  ('wisps', 1),
#  ('wishful', 1),
#  ('wishes', 2),
#  ('wishers', 1),
#  ('wished', 3),
#  ('wisest', 1),
#  ('wiser', 1),
#  ('wisely', 1),
#  ('wise', 3),
#  ('wisdom', 8),
#  ('wires', 9),
#  ('wire', 7),
#  ('wiped', 2),
#  ('wintry', 1),
#  ('winter', 5),
#  ('wins', 1),
#  ('winning', 1),
#  ('wings', 5),
#  ('winger', 5),
#  ('wing', 10),
#  ('wine', 4),
#  ('windy', 1),
#  ('windswept', 1),
#  ('windshield', 3),
#  ('winds', 15),
#  ('windproof', 1),
#  ('windows', 8),
#  ('window', 12),
#  ('winding', 7),
#  ('windblown', 1),
#  ('wind', 23),
#  ('winced', 1),
#  ('wince', 1),
#  ('win', 3),
#  ('willpower', 1),
#  ('willowy', 1),
#  ('willing', 2),
#  ('willfulness', 1),
#  ('willed', 1),
#  ('will', 176),
#  ('wildness', 2),
#  ('wildly', 2),
#  ('wildflowers', 1),
#  ('wilderness', 7),
#  ('wild', 11),
#  ('wiggle', 1),
#  ('wife', 8),
#  ('widened', 1),
#  ('wide', 13),
#  ('wickedly', 1),
#  ('why', 26),
#  ('whose', 15),
#  ('whore', 1),
#  ('whooped', 2),
#  ('whom', 2),
#  ('wholesaling', 1),
#  ('wholeness', 1),
#  ('whole', 3),
#  ('whoever', 1),
#  ('who', 167),
#  ('whittled', 1),
#  ('whitening', 1),
#  ('white', 21),
#  ('whistled', 1),
#  ('whispering', 6),
#  ('whispered', 16),
#  ('whisper', 3),
#  ('whiskey', 1),
#  ('whisked', 1),
#  ('whisk', 2),
#  ('whirlpools', 1),
#  ('whirling', 1),
#  ('whirled', 1),
#  ('whine', 1),
#  ('whimpered', 2),
#  ('while', 51),
#  ('whichever', 1),
#  ('which', 87),
#  ('whether', 6),
#  ('wherever', 2),
#  ('where', 112),
#  ('whenever', 3),
#  ('when', 273),
#  ('wheeze', 1),
#  ('wheel', 2),
#  ('wheedling', 1),
#  ('whatever', 12),
#  ('what', 201),
#  ('wetness', 1),
#  ('wet', 5),
#  ('westward', 2),
#  ('western', 14),
#  ('west', 49),
#  ('weren', 1),
#  ('were', 523),
#  ('wept', 7),
#  ('went', 31),
#  ('well', 47),
#  ('welfare', 1),
#  ('welcomed', 1),
#  ('welcome', 4),
#  ('weight', 15),
#  ('weighing', 1),
#  ('weighed', 1),
#  ('weeping', 3),
#  ('weep', 1),
#  ('weeks', 19),
#  ('weekends', 2),
#  ('weekend', 2),
#  ('week', 11),
#  ('wednesday', 1),
#  ('wedged', 2),
#  ('wedge', 1),
#  ('wedding', 2),
#  ('weaving', 3),
#  ('weave', 4),
#  ('weatherproof', 1),
#  ('weather', 21),
#  ('weary', 7),
#  ('wearing', 6),
#  ('weariness', 4),
#  ('wearily', 2),
#  ('wearied', 1),
#  ('wear', 2),
#  ('weapon', 1),
#  ('wealth', 1),
#  ('weakness', 3),
#  ('weakly', 2),
#  ('weakling', 1),
#  ('weakest', 3),
#  ('weaker', 8),
#  ('weakening', 4),
#  ('weakened', 4),
#  ('weaken', 3),
#  ('weak', 27),
#  ('we', 1226),
#  ('ways', 17),
#  ('way', 164),
#  ('waxy', 1),
#  ('waving', 1),
#  ('wavered', 1),
#  ('waved', 3),
#  ('wave', 3),
#  ('waters', 1),
#  ('waterfront', 1),
#  ('water', 36),
#  ('watching', 17),
#  ('watches', 1),
#  ('watched', 16),
#  ('watch', 16),
#  ('wasting', 3),
#  ('wasted', 6),
#  ('waste', 11),
#  ('wassenhove', 3),
#  ('wasn', 15),
#  ('washing', 1),
#  ('washers', 5),
#  ('washed', 3),
#  ('wash', 1),
#  ('was', 1430),
#  ('wary', 2),
#  ('warning', 2),
#  ('warned', 1),
#  ('warmth', 17),
#  ('warmly', 3),
#  ('warming', 3),
#  ('warmest', 5),
#  ('warmer', 2),
#  ('warmed', 6),
#  ('warm', 48),
#  ('ward', 2),
#  ('war', 1),
#  ('wants', 3),
#  ('wanting', 3),
#  ('wanted', 52),
#  ('want', 39),
#  ('wandering', 2),
#  ('wandered', 1),
#  ('wander', 3),
#  ('walls', 6),
#  ('wallets', 1),
#  ('walled', 1),
#  ('wall', 37),
#  ('walks', 1),
#  ('walking', 17),
#  ('walked', 24),
#  ('walk', 28),
#  ('waking', 2),
#  ('wake', 6),
#  ('waiting', 29),
#  ('waiter', 1),
#  ('waited', 22),
#  ('wait', 32),
#  ('waist', 1),
#  ('wailed', 2),
#  ('wail', 1),
#  ('wading', 1),
#  ('wade', 1),
#  ('vulnerable', 1),
#  ('vulnerability', 1),
#  ('vows', 1),
#  ('vowed', 3),
#  ('vow', 1),
#  ('voracious', 1),
#  ('vomit', 1),
#  ('volunteers', 1),
#  ('volunteered', 2),
#  ('void', 5),
#  ('voices', 3),
#  ('voice', 46),
#  ('vizintin', 9),
#  ('vividly', 1),
#  ('vivid', 1),
#  ('vital', 1),
#  ('visualizing', 1),
#  ('visors', 1),
#  ('visiting', 2),
#  ('visit', 4),
#  ('vision', 3),
#  ('visible', 2),
#  ('visibility', 3),
#  ('vise', 1),
#  ('viscerally', 2),
#  ('visceral', 2),
#  ('virtuous', 1),
#  ('virtuoso', 1),
#  ('virtuosity', 1),
#  ('virtually', 1),
#  ('virgin', 2),
#  ('vip', 1),
#  ('violet', 1),
#  ('violently', 5),
#  ('violent', 6),
#  ('violence', 2),
#  ('violation', 1),
#  ('villaro', 4),
#  ('villagers', 1),
#  ('village', 3),
#  ('vigorous', 2),
#  ('vigor', 1),
#  ('vigilant', 1),
#  ('vigil', 1),
#  ('views', 1),
#  ('view', 16),
#  ('viene', 2),
#  ('victory', 1),
#  ('victories', 2),
#  ('victims', 5),
#  ('viciously', 3),
#  ('vicious', 1),
#  ('vicinity', 1),
#  ('vibrate', 1),
#  ('vi', 5),
#  ('vessels', 1),
#  ('very', 89),
#  ('vertical', 4),
#  ('version', 1),
#  ('versatile', 1),
#  ('veronique', 24),
#  ('veronica', 3),
#  ('verge', 8),
#  ('verbally', 1),
#  ('verbalize', 1),
#  ('veranda', 1),
#  ('venture', 1),
#  ('venting', 1),
#  ('vented', 1),
#  ('venom', 1),
#  ('vengo', 2),
#  ('venezuela', 1),
#  ('velocity', 1),
#  ('veins', 5),
#  ('vehicles', 1),
#  ('vehicle', 1),
#  ('vegetable', 2),
#  ('veering', 1),
#  ('ve', 9),
#  ('vastness', 1),
#  ('vast', 7),
#  ('vasquez', 2),
#  ('vantage', 3),
#  ('vanishes', 1),
#  ('vanished', 5),
#  ('van', 3),
#  ('vamos', 1),
#  ('values', 4),
#  ('valued', 1),
#  ('value', 3),
#  ('valleys', 3),
#  ('valley', 29),
#  ('valiantly', 1),
#  ('valeta', 3),
#  ('vain', 1),
#  ('vacationed', 1),
#  ('vacation', 2),
#  ('vacant', 1),
#  ('utterly', 1),
#  ('usually', 6),
#  ('usual', 4),
#  ('using', 8),
#  ('uses', 1),
#  ('useless', 2),
#  ('useful', 1),
#  ('used', 20),
#  ('use', 27),
#  ('us', 519),
#  ('uruguayan', 15),
#  ('uruguay', 24),
#  ('urine', 1),
#  ('urinate', 1),
#  ('urgent', 3),
#  ('urgency', 3),
#  ('urged', 5),
#  ('urge', 12),
#  ('upward', 3),
#  ('upside', 1),
#  ('upset', 1),
#  ('upright', 1),
#  ('upper', 3),
#  ('upon', 11),
#  ('uplifting', 1),
#  ('upholstery', 3),
#  ('uphill', 2),
#  ('up', 161),
#  ('unzipped', 1),
#  ('unyielding', 1),
#  ('unusual', 1),
#  ('until', 67),
#  ('untested', 2),
#  ('unstable', 3),
#  ('unspeakable', 1),
#  ('unshakeable', 1),
#  ('unshakable', 1),
#  ('unsettling', 1),
#  ('unsettled', 1),
#  ('unsettle', 1),
#  ('unscripted', 1),
#  ('unscheduled', 1),
#  ('unruliness', 1),
#  ('unreal', 2),
#  ('unreachable', 1),
#  ('unquestioned', 1),
#  ('unpopular', 1),
#  ('unobstructed', 1),
#  ('unnaturally', 1),
#  ('unmistakable', 1),
#  ('unlucky', 1),
#  ('unlikely', 1),
#  ('unless', 5),
#  ('unleashed', 1),
#  ('unknown', 15),
#  ('universe', 2),
#  ('unintentionally', 1),
#  ('uninjured', 6),
#  ('unimaginable', 2),
#  ('unifying', 1),
#  ('uniforms', 1),
#  ('unified', 2),
#  ('unhurried', 1),
#  ('unharmed', 1),
#  ('unguided', 1),
#  ('unformed', 2),
#  ('unforgiving', 2),
#  ('unforgettable', 1),
#  ('unfolds', 1),
#  ('unfolded', 1),
#  ('unfocused', 1),
#  ('unflinching', 1),
#  ('unfiltered', 2),
#  ('unfamiliar', 1),
#  ('unexpected', 2),
#  ('underworld', 1),
#  ('understood', 38),
#  ('understands', 1),
#  ('understanding', 4),
#  ('understand', 25),
#  ('underscored', 1),
#  ('underneath', 1),
#  ('under', 35),
#  ('uncovered', 3),
#  ('unconventional', 1),
#  ('uncontrollably', 2),
#  ('uncompromising', 1),
#  ('uncomplicated', 1),
#  ('uncomfortably', 1),
#  ('uncomfortable', 1),
#  ('unclimbable', 1),
#  ('uncle', 1),
#  ('uncertainty', 2),
#  ('uncertain', 4),
#  ('unbearable', 4),
#  ('unapologetic', 1),
#  ('unaccounted', 1),
#  ('unable', 1),
#  ('una', 1),
#  ('un', 2),
#  ('ukrainian', 1),
#  ('ukraine', 2),
#  ('ugly', 1),
#  ('ugliness', 1),
#  ('uglier', 1),
#  ('u', 1),
#  ('tyrell', 3),
#  ('tying', 2),
#  ('two', 78),
#  ('twisted', 3),
#  ('twist', 1),
#  ('twin', 1),
#  ('twilight', 2),
#  ('twice', 4),
#  ('twenty', 20),
#  ('twenties', 2),
#  ('twelve', 3),
#  ('twelfth', 2),
#  ('tv', 4),
#  ('turns', 7),
#  ('turning', 6),
#  ('turned', 45),
#  ('turn', 20),
#  ('turf', 3),
#  ('turcatti', 3),
#  ('turbulent', 1),
#  ('turbulence', 7),
#  ('turboprop', 1),
#  ('tupongato', 1),
#  ('tunneling', 1),
#  ('tunnel', 1),
#  ('tuned', 1),
#  ('tune', 3),
#  ('tumbled', 5),
#  ('tumble', 2),
#  ('tugging', 2),
#  ('tugged', 1),
#  ('tug', 1),
#  ('tuesday', 1),
#  ('tucked', 2),
#  ('tube', 3),
#  ('tu', 1),
#  ('trying', 23),
#  ('try', 29),
#  ('truth', 5),
#  ('trustworthy', 1),
#  ('trusting', 1),
#  ('trusted', 9),
#  ('trust', 18),
#  ('trunks', 1),
#  ('truly', 7),
#  ('true', 23),
#  ('trudged', 2),
#  ('trucks', 1),
#  ('truck', 1),
#  ('trousers', 3),
#  ('troubling', 2),
#  ('troubled', 3),
#  ('trouble', 5),
#  ('trophy', 1),
#  ('trivial', 1),
#  ('triumph', 2),
#  ('trips', 1),
#  ('tripped', 2),
#  ('trip', 29),
#  ('trio', 1),
#  ('trim', 1),
#  ('triggered', 1),
#  ('tries', 1),
#  ('tried', 55),
#  ('tricks', 1),
#  ('trickling', 1),
#  ('trickle', 1),
#  ('tricked', 1),
#  ('trick', 2),
#  ('trial', 1),
#  ('tremor', 1),
#  ('tremendous', 1),
#  ('trembling', 1),
#  ('trembled', 2),
#  ('tremble', 2),
#  ('trekking', 5),
#  ('trekked', 3),
#  ('trek', 22),
#  ('trees', 5),
#  ('tree', 3),
#  ('treatment', 2),
#  ('treated', 6),
#  ('treat', 2),
#  ('treasures', 2),
#  ('treasure', 4),
#  ('treadmill', 1),
#  ('treacherous', 5),
#  ('traveling', 6),
#  ('traveled', 9),
#  ('travel', 8),
#  ('trauma', 1),
#  ('trash', 1),
#  ('trappings', 2),
#  ('trapping', 2),
#  ('trapped', 28),
#  ('trap', 1),
#  ('transportation', 1),
#  ('transmitter', 2),
#  ('transmission', 1),
#  ('translation', 1),
#  ('transistor', 3),
#  ('transgressions', 1),
#  ('transforming', 1),
#  ('tranquillity', 1),
#  ('trancelike', 1),
#  ('trance', 2),
#  ('trampled', 1),
#  ('trains', 2),
#  ('training', 3),
#  ('trained', 2),
#  ('train', 3),
#  ('trails', 2),
#  ('trailing', 1),
#  ('trailer', 1),
#  ('trail', 4),
#  ('traditional', 1),
#  ('trade', 1),
#  ('tractors', 1),
#  ('traction', 2),
#  ('tracks', 8),
#  ('tracking', 1),
#  ('track', 6),
#  ('traces', 1),
#  ('trace', 3),
#  ('toy', 1),
#  ('toxins', 1),
#  ('town', 6),
#  ('towers', 1),
#  ('towering', 4),
#  ('towered', 1),
#  ('tower', 1),
#  ('towels', 1),
#  ('toward', 49),
#  ('tourist', 1),
#  ('touring', 1),
#  ('toughness', 1),
#  ('toughest', 1),
#  ('tough', 7),
#  ('touchstone', 1),
#  ('touching', 1),
#  ('touches', 1),
#  ('touched', 5),
#  ('touch', 6),
#  ('total', 5),
#  ('tossing', 3),
#  ('tossed', 7),
#  ('toss', 4),
#  ('torturing', 1),
#  ('tortured', 4),
#  ('torture', 1),
#  ('torso', 1),
#  ('torrential', 1),
#  ('torrent', 1),
#  ('torn', 6),
#  ('tormented', 5),
#  ('tore', 2),
#  ('toppling', 2),
#  ('toppled', 1),
#  ('topped', 1),
#  ('top', 26),
#  ('tools', 4),
#  ('tool', 1),
#  ('took', 65),
#  ('too', 97),
#  ('tons', 5),
#  ('tonight', 3),
#  ('tongues', 1),
#  ('tongue', 2),
#  ('tones', 1),
#  ('tone', 1),
#  ('tomorrow', 13),
#  ('tomb', 2),
#  ('tomatoes', 1),
#  ('tolerate', 2),
#  ('told', 80),
#  ('toiling', 1),
#  ('toilet', 1),
#  ('toggles', 1),
#  ('toggle', 1),
#  ('together', 46),
#  ('toes', 3),
#  ('toe', 1),
#  ('toddler', 1),
#  ('today', 5),
#  ('toboggan', 1),
#  ('to', 2400),
#  ('titan', 1),
#  ('tissues', 1),
#  ('tissue', 1),
#  ('tireless', 1),
#  ('tired', 7),
#  ('tipping', 1),
#  ('tip', 6),
#  ('tiny', 10),
#  ('tintin', 48),
#  ('tinted', 1),
#  ('tinny', 1),
#  ('tinkers', 1),
#  ('tinkering', 1),
#  ('tinkered', 2),
#  ('tingling', 1),
#  ('tinged', 1),
#  ('tin', 1),
#  ('timing', 1),
#  ('timidity', 1),
#  ('times', 22),
#  ('time', 182),
#  ('tilting', 1),
#  ('tilted', 4),
#  ('tilt', 1),
#  ('tile', 2),
#  ('tigre', 1),
#  ('tightly', 3),
#  ('tightened', 3),
#  ('tight', 5),
#  ('tierra', 1),
#  ('tied', 6),
#  ('tie', 4),
#  ('tidy', 1),
#  ('tide', 4),
#  ('ticking', 1),
#  ('tickets', 1),
#  ('thursday', 1),
#  ('thundered', 3),
#  ('thunderclap', 1),
#  ('thunder', 2),
#  ('thumped', 1),
#  ('thrust', 1),
#  ('thrown', 2),
#  ('throwing', 2),
#  ('throw', 5),
#  ('throughout', 3),
#  ('through', 134),
#  ('throttle', 1),
#  ('throbbing', 1),
#  ('throbbed', 1),
#  ('throat', 9),
#  ('thriving', 1),
#  ('thrived', 1),
#  ('thrive', 1),
#  ('threw', 6),
#  ('three', 49),
#  ('threats', 1),
#  ('threatening', 1),
#  ('threatened', 1),
#  ('threat', 2),
#  ('threads', 1),
#  ('threading', 1),
#  ('thread', 3),
#  ('thousands', 2),
#  ('thousand', 15),
#  ('thoughts', 31),
#  ('thought', 106),
#  ('though', 23),
#  ('those', 74),
#  ('this', 320),
#  ('thirty', 15),
#  ('thirteenth', 1),
#  ('thirsty', 1),
#  ('thirst', 9),
#  ('thirds', 1),
#  ('third', 7),
#  ('thinning', 3),
#  ('thinnest', 1),
#  ('thinness', 1),
#  ('thinned', 1),
#  ('thinks', 1),
#  ('thinking', 36),
#  ('thinker', 1),
#  ('think', 77),
#  ('things', 58),
#  ('thing', 31),
#  ('thin', 36),
#  ('thighs', 1),
#  ('thickheaded', 1),
#  ('thickening', 1),
#  ('thickened', 1),
#  ('thick', 17),
#  ('they', 360),
#  ('these', 98),
#  ('thermal', 1),
#  ('there', 269),
#  ('therapist', 1),
#  ('theory', 2),
#  ('then', 195),
#  ('themselves', 18),
#  ('them', 275),
#  ('their', 227),
#  ('the', 5346),
#  ('thawed', 1),
#  ('thaw', 1),
#  ('that', 1001),
#  ('thanks', 3),
#  ('thanked', 1),
#  ('thank', 4),
#  ('than', 118),
#  ('texture', 1),
#  ('tethered', 1),
#  ('tether', 1),
#  ('testing', 2),
#  ('test', 5),
#  ('terror', 7),
#  ('terrifying', 6),
#  ('terrified', 9),
#  ('terribly', 8),
#  ('terrible', 12),
#  ('terrain', 5),
#  ('terms', 3),
#  ('tents', 2),
#  ('tenth', 1),
#  ('tentative', 1),
#  ('tensions', 1),
#  ('tension', 1),
#  ('tenseness', 1),
#  ('tense', 2),
#  ('tending', 2),
#  ('tenderness', 2),
#  ('tenderly', 2),
#  ('tended', 1),
#  ('tend', 4),
#  ('tenacity', 2),
#  ('ten', 17),
#  ('tempted', 1),
#  ('temporary', 3),
#  ('temples', 1),
#  ('tempered', 2),
#  ('temperatures', 13),
#  ('temperature', 5),
#  ('temperaments', 2),
#  ('temperament', 2),
#  ('temper', 3),
#  ('tells', 1),
#  ('telling', 8),
#  ('tell', 39),
#  ('television', 4),
#  ('teeth', 3),
#  ('teetering', 1),
#  ('teens', 1),
#  ('teddy', 1),
#  ('techniques', 4),
#  ('technique', 1),
#  ('technical', 3),
#  ('teased', 2),
#  ('tease', 1),
#  ('tears', 9),
#  ('tearing', 2),
#  ('tear', 2),
#  ('teamwork', 1),
#  ('teams', 6),
#  ('teammates', 9),
#  ('teammate', 7),
#  ('team', 50),
#  ('teachings', 2),
#  ('teaching', 7),
#  ('teachers', 1),
#  ('teach', 2),
#  ('taxi', 1),
#  ('taught', 16),
#  ('tattered', 1),
#  ('taste', 4),
#  ('task', 5),
#  ('tarp', 1),
#  ('target', 2),
#  ('tapping', 3),
#  ('tangled', 4),
#  ('tangle', 5),
#  ('tame', 1),
#  ('tallest', 4),
#  ('taller', 1),
#  ('tall', 14),
#  ('talking', 11),
#  ('talked', 8),
#  ('talk', 9),
#  ('talent', 1),
#  ('taking', 12),
#  ('takes', 3),
#  ('takeoff', 1),
#  ('taken', 29),
#  ('take', 60),
#  ('tailors', 1),
#  ('tail', 39),
#  ('tacklers', 3),
#  ('tackler', 4),
#  ('tackle', 1),
#  ('taboo', 1),
#  ('table', 2),
#  ('t', 290),
#  ('systems', 1),
#  ('system', 7),
#  ('symptoms', 1),
#  ('symbol', 1),
#  ('swung', 1),
#  ('swore', 1),
#  ('sword', 1),
#  ('swooping', 1),
#  ('swooped', 1),
#  ('swoon', 1),
#  ('swollen', 3),
#  ('swiveled', 1),
#  ('switzerland', 1),
#  ('switching', 1),
#  ('switch', 1),
#  ('swirls', 1),
#  ('swirling', 6),
#  ('swirled', 1),
#  ('swinging', 4),
#  ('swing', 2),
#  ('swimming', 2),
#  ('swimmer', 1),
#  ('swim', 3),
#  ('swigs', 1),
#  ('swiftly', 1),
#  ('swifter', 1),
#  ('swift', 4),
#  ('swerved', 1),
#  ('swept', 10),
#  ('swells', 1),
#  ('swelling', 1),
#  ('swelled', 4),
#  ('swell', 1),
#  ('sweetness', 3),
#  ('sweet', 1),
#  ('sweeping', 1),
#  ('sweaters', 4),
#  ('sweater', 1),
#  ('sweat', 1),
#  ('swear', 3),
#  ('swaying', 1),
#  ('sway', 1),
#  ('swallowing', 1),
#  ('swallowed', 1),
#  ('swallow', 4),
#  ('susy', 70),
#  ('sustained', 1),
#  ('suspension', 1),
#  ('suspendieron', 1),
#  ('suspended', 1),
#  ('suspected', 2),
#  ('suspect', 1),
#  ('survivors', 67),
#  ('survivor', 9),
#  ('surviving', 4),
#  ('survives', 3),
#  ('survived', 11),
#  ('survive', 46),
#  ('survival', 17),
#  ('surveyed', 2),
#  ('surrounding', 5),
#  ('surrounded', 13),
#  ('surrendered', 3),
#  ('surrender', 12),
#  ('surraco', 1),
#  ('surprising', 1),
#  ('surprises', 1),
#  ('surprised', 6),
#  ('surprise', 2),
#  ('surplus', 1),
#  ('surges', 1),
#  ('surged', 1),
#  ('surge', 8),
#  ('surface', 12),
#  ('surf', 1),
#  ('surely', 7),
#  ('sure', 32),
#  ('supreme', 1),
#  ('suppressing', 1),
#  ('suppressed', 1),
#  ('supposed', 3),
#  ('suppose', 1),
#  ('supporters', 5),
#  ('supporter', 1),
#  ('support', 5),
#  ('supply', 5),
#  ('supplies', 8),
#  ('supermarket', 1),
#  ('superhuman', 1),
#  ('superficial', 1),
#  ('sunshine', 3),
#  ('sunset', 8),
#  ('sunny', 3),
#  ('sunned', 1),
#  ('sunlight', 2),
#  ('sunken', 1),
#  ('sunk', 1),
#  ('sunglasses', 3),
#  ('sundown', 2),
#  ('sun', 50),
#  ('summoning', 1),
#  ('summoned', 1),
#  ('summon', 1),
#  ('summits', 6),
#  ('summit', 25),
#  ('summertime', 1),
#  ...]

# %%
from platform import python_version
python_version()
# Out:
# '3.12.6'

# %%
# !pip3.12 install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\3000124\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\3000124\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\3000124\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\3000124\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\3000124\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\3000124\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('stopwords')
nltk.download('vader_lexicon')

from nltk.corpus import stopwords
english_stopwords = stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\3000124\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\3000124\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
filtered_word = []
for count, word in d_list:
    if word not in english_stopwords:
        filtered_word.append((word,count))

# %%
filtered_word[:10]
# Out:
# [(1, 'zones'),
#  (1, 'zone'),
#  (1, 'zombies'),
#  (1, 'zolder'),
#  (1, 'zigzagged'),
#  (4, 'zero'),
#  (23, 'zerbino'),
#  (1, 'zeal'),
#  (1, 'zandvoort'),
#  (1, 'zampa')]

# %% [markdown]
# # Sentiment Analysis: what is the most positive and the most negative chapter?

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
score = analyzer.polarity_scores("Hey, look how beautiful the trees are. I hate then. I really hate them")

# %%
if score["pos"] > score["neg"]:
    print("It is a positive text")
else:
    print("It is a negative text")
# Out:
# It is a negative text

# %%
analyzer.polarity_scores(book)
# Out:
# {'neg': 0.116, 'neu': 0.76, 'pos': 0.125, 'compound': 1.0}

# %% [markdown]
# ### Chapters sentiment

# %%
import re
pattern = re.compile("chapter [0-9]+")
chapters = re.split(pattern,book)

# %%
chapters = chapters[1:]

# %%
for nr,chapter in enumerate(chapters):
    score = analyzer.polarity_scores(chapter)
print(nr + 1,score)
# Out:
# {'neg': 0.365, 'neu': 0.443, 'pos': 0.192, 'compound': -0.5423}
